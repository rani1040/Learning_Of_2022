# %%
import hdfc

# %%
rani = hdfc.Atm()
# Out:
# Hii HDFC Bank
# Create a four Digit Pin1040
#  Your Pin has been Created

# %%
rani.deposite()
# Out:
# Enter you Four Digit Pin :1040
# Enter the Amount you want to deposite : 1000
#  Deposite Succesfull

# %%
type(rani)
# Out:
# hdfc.Atm

# %%
rani

# %%
rani = hdfc.Atm()
# Out:
# Hii HDFC Bank
# Create a four Digit Pin2034
#  Your Pin has been Created

# %%
rani.deposite()
# Out:
# Enter you Four Digit Pin :2034
# Enter the Amount you want to deposite : 500
#  Deposite Succesfull

# %%
rani.checkbalance()
# Out:
# Enter you Four Digit Pin2034
# Your current balance is  500

# %% [markdown]
# ## Instance Variable:
# * for every object this instance variable value will be different.
# * Object.variable_name = instance_variable.
# * variable jiska ek hi sath alg alg value set ho jaye.
#
# ## Class Variable .
# * For every object this class variable value is same.
# * Class_name.variable_name = class_variable.
#
#
# For example
# if we have created our account in hdfc bank than individaul account number will be instance variable
# we will access them like this :
# * self.accNo
#
# on the same page what will will IFC Code of each individual it will be same so tho access that we will be using this :
# * Atm.ifc
#
# ### Difference Between class and instance variable ?

# %%
import hdfc

# %%
rani = hdfc.Atm()
# Out:
# Hii HDFC Bank
# Create a four Digit Pin
#  Your Pin has been Created

# %% [markdown]
# you are junior programmer you can access the function of that class but you cannot access the data of that class .
# why ?
# beacause if you are accessing it , that means you can make changes into that , and that will impact the code for example
# you can change the variable of instance variable .
# and if you are making changes into class variable then this will create a big mess and it will create permanent bug into software and you cannot create any furthur object .
# thats where the concept of encapsulation comes into picture where we are not exposing our data directly .
#
# Now what if  junior developer need to access that data ,in that we dont have to expose our data what we can so it
# we can create two method :
# * get : this will show the data , means you can only access the data.
# * set : you can set the value of data.
# hidding this data is known as abstration .

# %% [markdown]
# **To Do abstaction put underscore in front of variable**
# in java this is same as private

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# # DRY : Dont repeat yourself

# %% [markdown]
# # To Do Inheritance put into bracket

# %% [markdown]
# # To Do Polymorphism (same function)
# * **Multilevel Interiance :**
# * **Method Overriding :**
# * **Method Overloading** :
#
#
# in java we cannot inheritent from more than one class .

# %% [markdown]
# ## Multiple Inteheritance :
# * you can import from two different class and it will call that method use preference or order is first
# example pappu(mummy,pappa)
# mummy class will be called out
# example pappu(pappa,mummy)
# pappa class will be called out
#
# and this is known as **method order resolution** it will decide whose function will be called when conflict occurrs

# %% [markdown]
# why in python everything is not private?
# :) because python is for adult .
# example mohobathe.
